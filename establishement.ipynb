# %%
import pandas as pd

# %%
df = pd.read_csv('./Etablissements (3).csv', sep=';')

# %%
df.head()
# Out:
#    id  type_hebergement_id  lieu_id       nom_etablissement  etoiles  \
# 0   1                  3.0      512     RESIDENCE LE MANUJO      1.0
# 1   2                  3.0      387  RESIDENCE LES ETERLOUS      3.0
# 2   3                  5.0      512        CENTRE EDELWEISS      NaN
# 3   4                  5.0      512   CLUB MMV LE VAL CENIS      NaN
# 4   6                  5.0      512              ARBA NEIGE      NaN
#
#                                              adresse tel1 tel2  fax mail  \
# 0                                      LANSLEVILLARD  NaN  NaN  NaN  NaN
# 1                     73480 Bonneval-sur-Arc, France  NaN  NaN  NaN  NaN
# 2       2 Rue du Mont-Cenis, 73480 Val-Cenis, France  NaN  NaN  NaN  NaN
# 3  Quartier des Sablons, Chem. des Crueux, 73480 ...  NaN  NaN  NaN  NaN
# 4       322 Rue des Essarts, 73480 Val-Cenis, France  NaN  NaN  NaN  NaN
#
#     latitude  longitude  localisation_validee                google_map_id
# ...

# %%
new_df = pd.DataFrame()
new_df['id'] = df['id'].to_list()
new_df['lieu_id'] = df['lieu_id'].to_list()
new_df['nom_etablissement'] = df['nom_etablissement'].to_list()
new_df['adresse'] = df['adresse'].to_list()

# %%
new_df.head()
# Out:
#    id  lieu_id       nom_etablissement  \
# 0   1      512     RESIDENCE LE MANUJO
# 1   2      387  RESIDENCE LES ETERLOUS
# 2   3      512        CENTRE EDELWEISS
# 3   4      512   CLUB MMV LE VAL CENIS
# 4   6      512              ARBA NEIGE
#
#                                              adresse
# 0                                      LANSLEVILLARD
# 1                     73480 Bonneval-sur-Arc, France
# 2       2 Rue du Mont-Cenis, 73480 Val-Cenis, France
# 3  Quartier des Sablons, Chem. des Crueux, 73480 ...
# 4       322 Rue des Essarts, 73480 Val-Cenis, France

# %%
new_df.to_csv('new_destination.csv', index=False)
